# %%
import os
os.chdir('./SkipGNN')

# %%
# !python train.py \
    --epochs 15 \
    --lr 5e-4 \
    --batch_size 256 \
    --hidden1 64 \
    --hidden2 16 \
    --hidden_decode1 512 \
    --network_type DTI \
    --data_path '../../../../scratch/kh2383/IGCN/data/DTI/BIOSNAP/fold1'
    --input_type one_hot
# Out:
# Loading DTI dataset...
# Start Training...
# -------- Epoch 1 --------
# epoch: 1/ iteration: 1/ loss_train: 0.6881942749023438
# epoch: 0001 loss_train: 0.4146 auroc_train: 0.8411 loss_val: 0.4544 auroc_val: 0.8848 auprc_val: 0.8922 f1_val: 0.7362 time: 12.2537s
# -------- Epoch 2 --------
# epoch: 2/ iteration: 1/ loss_train: 0.4589182436466217
# epoch: 0002 loss_train: 0.5044 auroc_train: 0.9037 loss_val: 0.4399 auroc_val: 0.9098 auprc_val: 0.9153 f1_val: 0.7834 time: 12.2591s
# -------- Epoch 3 --------
# epoch: 3/ iteration: 1/ loss_train: 0.4010852873325348
# epoch: 0003 loss_train: 0.3807 auroc_train: 0.9217 loss_val: 0.4573 auroc_val: 0.9223 auprc_val: 0.9251 f1_val: 0.7599 time: 12.1459s
# -------- Epoch 4 --------
# epoch: 4/ iteration: 1/ loss_train: 0.377285361289978
# epoch: 0004 loss_train: 0.4178 auroc_train: 0.9306 loss_val: 0.3544 auroc_val: 0.9258 auprc_val: 0.9284 f1_val: 0.7905 time: 12.2243s
# -------- Epoch 5 --------
# ...

# %%
# !python train_link_prediction_IGCN_NoGate.py \
    --epochs 15 \
    --lr 5e-4 \
    --batch_size 256 \0.884
    --hidden1 64 \
    --hidden2 16 \
    --hidden_decode1 512 \
    --network_type DDI \
    --data_path '../../../../scratch/kh2383/IGCN/data/DDI/BIOSNAP_Full/fold1'
    --input_type one_hot
# Out:
# Loading DDI dataset...
# Start Training...
# -------- Epoch 1 --------
# epoch: 1/ iteration: 1/ loss_train: 0.6937984228134155
# epoch: 1/ iteration: 101/ loss_train: 0.43508678674697876
# epoch: 1/ iteration: 201/ loss_train: 0.4298311471939087
# epoch: 0001 loss_train: 0.3810 auroc_train: 0.8543 loss_val: 0.4200 auroc_val: 0.8806 auprc_val: 0.8605 f1_val: 0.7991 time: 72.3379s
# -------- Epoch 2 --------
# epoch: 2/ iteration: 1/ loss_train: 0.37204575538635254
# epoch: 2/ iteration: 101/ loss_train: 0.4388185143470764
# epoch: 2/ iteration: 201/ loss_train: 0.39213821291923523
# epoch: 0002 loss_train: 0.4431 auroc_train: 0.8798 loss_val: 0.4195 auroc_val: 0.8824 auprc_val: 0.8590 f1_val: 0.7368 time: 72.2304s
# -------- Epoch 3 --------
# epoch: 3/ iteration: 1/ loss_train: 0.41546881198883057
# epoch: 3/ iteration: 101/ loss_train: 0.40721583366394043
# epoch: 3/ iteration: 201/ loss_train: 0.37942203879356384
# ...

# %%
# !python train_link_prediction_IGCN_NoGate.py \
    --epochs 15 \
    --lr 5e-4 \
    --batch_size 256 \
    --hidden1 64 \
    --hidden2 16 \
    --hidden_decode1 512 \
    --network_type PPI \
    --data_path '../../../../scratch/kh2383/IGCN/data/PPI/HuRI/fold1'
    --input_type one_hot
# Out:
# Loading PPI dataset...
# Start Training...
# -------- Epoch 1 --------
# epoch: 1/ iteration: 1/ loss_train: 0.694492518901825
# epoch: 1/ iteration: 101/ loss_train: 0.34053438901901245
# epoch: 0001 loss_train: 0.3908 auroc_train: 0.8834 loss_val: 0.3448 auroc_val: 0.9079 auprc_val: 0.9200 f1_val: 0.8259 time: 36.9382s
# -------- Epoch 2 --------
# epoch: 2/ iteration: 1/ loss_train: 0.43066561222076416
# epoch: 2/ iteration: 101/ loss_train: 0.38629263639450073
# epoch: 0002 loss_train: 0.4148 auroc_train: 0.9206 loss_val: 0.3017 auroc_val: 0.9095 auprc_val: 0.9224 f1_val: 0.8253 time: 36.9005s
# -------- Epoch 3 --------
# epoch: 3/ iteration: 1/ loss_train: 0.42659497261047363
# epoch: 3/ iteration: 101/ loss_train: 0.39215707778930664
# epoch: 0003 loss_train: 0.3382 auroc_train: 0.9258 loss_val: 0.3753 auroc_val: 0.9080 auprc_val: 0.9196 f1_val: 0.7981 time: 37.0038s
# -------- Epoch 4 --------
# epoch: 4/ iteration: 1/ loss_train: 0.3335167467594147
# ...

# %%
# !python train_link_prediction_IGCN_NoGate.py \
    --epochs 15 \
    --lr 5e-4 \
    --batch_size 256 \
    --hidden1 64 \
    --hidden2 16 \
    --hidden_decode1 512 \
    --network_type GDI \
    --data_path '/scratch/kh2383/IGCN/data/GDI/fold1'\
    --input_type one_hot
# Out:
# Loading GDI dataset...
# /home/kh2383/igcn/code/utils.py:312: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_data_t['Gene_ID'] = df_data_t['Gene_ID'].apply(str)
# Start Training...
# -------- Epoch 1 --------
# epoch: 1/ iteration: 1/ loss_train: 0.703494131565094
# epoch: 1/ iteration: 101/ loss_train: 0.32150447368621826
# epoch: 1/ iteration: 201/ loss_train: 0.35279881954193115
# epoch: 1/ iteration: 301/ loss_train: 0.31292614340782166
# epoch: 1/ iteration: 401/ loss_train: 0.28183573484420776
# epoch: 0001 loss_train: 0.3188 auroc_train: 0.9284 loss_val: 0.3234 auroc_val: 0.9071 auprc_val: 0.9235 f1_val: 0.8388 time: 116.2664s
# -------- Epoch 2 --------
# epoch: 2/ iteration: 1/ loss_train: 0.35889023542404175
# ...
